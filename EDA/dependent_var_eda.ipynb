# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("..\Datasets\Original\PrevalenceofUndernourishment_2016_2020_Percent_byCountry.csv")
df.head()
# Out:
#   Domain Code          Domain  Area Code (M49)         Area  Element Code  \
# 0        SDGB  SDG Indicators                4  Afghanistan          6121
# 1        SDGB  SDG Indicators                4  Afghanistan          6121
# 2        SDGB  SDG Indicators                4  Afghanistan          6121
# 3        SDGB  SDG Indicators                4  Afghanistan          6121
# 4        SDGB  SDG Indicators                4  Afghanistan          6121
#
#   Element Item Code (SDG)                                      Item  \
# 0   Value     SN_ITK_DEFC  2.1.1 Prevalence of undernourishment (%)
# 1   Value     SN_ITK_DEFC  2.1.1 Prevalence of undernourishment (%)
# 2   Value     SN_ITK_DEFC  2.1.1 Prevalence of undernourishment (%)
# 3   Value     SN_ITK_DEFC  2.1.1 Prevalence of undernourishment (%)
# 4   Value     SN_ITK_DEFC  2.1.1 Prevalence of undernourishment (%)
#
#    Year Code  Year Unit Value  Flag  Flag Description  \
# 0       2016  2016    %  22.2   NaN               NaN
# 1       2017  2017    %    23   NaN               NaN
# 2       2018  2018    %    24   NaN               NaN
# 3       2019  2019    %  26.9   NaN               NaN
# 4       2020  2020    %  29.8   NaN               NaN
#
#                                                 Note
# 0  Global | FAO, Statistics Division | Estimated ...
# 1  Global | FAO, Statistics Division | Estimated ...
# 2  Global | FAO, Statistics Division | Estimated ...
# 3  Global | FAO, Statistics Division | Estimated ...
# 4  Global | FAO, Statistics Division | Estimates ...

# %%
"""
Mapping:
    Dependent var: Use AreaCode(M49)
    Independent var:
        Consumer price indice: ISO3

Columns:
    ISO3
    Area Code (M49)
    Country Name
    var_name_year (order dependent var first then independent vars) 
    var_name_avg (after every var)
    var_name_unit (after every var)

'Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
       'Element', 'Item Code (SDG)', 'Item', 'Year Code', 'Year', 'Unit',
       'Value', 'Flag', 'Flag Description', 'Note'
"""
cols = ["Area Code (M49)", "Area", "Year", "Unit", "Value"]
trimmed_df = df[cols]

trimmed_df.shape
# Out:
# (1222, 5)
