# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("..\datasets\ConsumerPriceIndices_2016_2020_AllMths_ValueUS$_byCountry.csv")
df[df["Months"] == "December"]
# Out:
#       Domain Code                  Domain  Area Code (M49)         Area  \
# 11             CP  Consumer Price Indices                4  Afghanistan
# 23             CP  Consumer Price Indices                4  Afghanistan
# 35             CP  Consumer Price Indices                4  Afghanistan
# 47             CP  Consumer Price Indices                4  Afghanistan
# 59             CP  Consumer Price Indices                4  Afghanistan
# ...           ...                     ...              ...          ...
# 12131          CP  Consumer Price Indices              716     Zimbabwe
# 12143          CP  Consumer Price Indices              716     Zimbabwe
# 12155          CP  Consumer Price Indices              716     Zimbabwe
# 12167          CP  Consumer Price Indices              716     Zimbabwe
# 12179          CP  Consumer Price Indices              716     Zimbabwe
#
#        Year Code  Year  Item Code                                        Item  \
# 11          2016  2016      23013  Consumer Prices, Food Indices (2015 = 100)
# 23          2017  2017      23013  Consumer Prices, Food Indices (2015 = 100)
# 35          2018  2018      23013  Consumer Prices, Food Indices (2015 = 100)
# 47          2019  2019      23013  Consumer Prices, Food Indices (2015 = 100)
# 59          2020  2020      23013  Consumer Prices, Food Indices (2015 = 100)
# ...          ...   ...        ...                                         ...
# 12131       2016  2016      23013  Consumer Prices, Food Indices (2015 = 100)
# 12143       2017  2017      23013  Consumer Prices, Food Indices (2015 = 100)
# 12155       2018  2018      23013  Consumer Prices, Food Indices (2015 = 100)
# 12167       2019  2019      23013  Consumer Prices, Food Indices (2015 = 100)
# 12179       2020  2020      23013  Consumer Prices, Food Indices (2015 = 100)
#
#        Months Code    Months  Unit        Value Flag  \
# 11            7012  December   NaN   108.916832    X
# 23            7012  December   NaN   113.832502    X
# 35            7012  December   NaN   113.490296    X
# 47            7012  December   NaN   119.067918    X
# 59            7012  December   NaN   128.002089    A
# ...            ...       ...   ...          ...  ...
# 12131         7012  December   NaN    96.878032    X
# 12143         7012  December   NaN   103.383454    X
# 12155         7012  December   NaN   158.767447    X
# 12167         7012  December   NaN  1300.732638    X
# 12179         7012  December   NaN  5806.528164    X
#
#                               Flag Description               Note
# 11     Figure from international organizations  base year is 2015
# 23     Figure from international organizations  base year is 2015
# 35     Figure from international organizations  base year is 2015
# 47     Figure from international organizations  base year is 2015
# 59                             Official figure  base year is 2015
# ...                                        ...                ...
# 12131  Figure from international organizations  base year is 2015
# 12143  Figure from international organizations  base year is 2015
# 12155  Figure from international organizations  base year is 2015
# 12167  Figure from international organizations  base year is 2015
# 12179  Figure from international organizations  base year is 2015
#
# [1015 rows x 15 columns]

# %% [markdown]
# ## Skeleton dataframe

# %%
columns = ["Area Code (M49)"]
df_new = df[columns[0]].unique()
df_new = pd.DataFrame(df_new, columns=columns)
df_new.shape
# Out:
# (203, 1)

# %%
df_code = pd.read_csv("../datasets/AreaCode_ISO3Code_conversion.csv")
df_code = df_code[["Country", "ISO3 Code", "M49 Code"]]
df_new = df_new.join(df_code.set_index("M49 Code"), on="Area Code (M49)", validate="1:1")
df_new
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_41756\139787273.py:3: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_new = df_new.join(df_code.set_index("M49 Code"), on="Area Code (M49)", validate="1:1")
#      Area Code (M49)                             Country ISO3 Code
# 0                  4                         Afghanistan       AFG
# 1                248                       Åland Islands       ALA
# 2                  8                             Albania       ALB
# 3                 12                             Algeria       DZA
# 4                 20                             Andorra       AND
# ..               ...                                 ...       ...
# 198              862  Venezuela (Bolivarian Republic of)       VEN
# 199              704                            Viet Nam       VNM
# 200              887                               Yemen       YEM
# 201              894                              Zambia       ZMB
# 202              716                            Zimbabwe       ZWE
#
# [203 rows x 3 columns]

# %%
df_new.rename(columns={"iso3": "ISO3_Code", "Country": "Country_Name", "Area Code (M49)": "M49_Code"}, inplace=True)
df_new.head()
# Out:
#    M49_Code   Country_Name ISO3 Code
# 0         4    Afghanistan       AFG
# 1       248  Åland Islands       ALA
# 2         8        Albania       ALB
# 3        12        Algeria       DZA
# 4        20        Andorra       AND

# %%
df_new[df_new["Country_Name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [M49_Code, Country_Name, ISO3 Code]
# Index: []

# %%
# drop the null rows cause it's the legend
df_new.dropna(inplace=True)
df_new
# Out:
#      M49_Code                        Country_Name ISO3 Code
# 0           4                         Afghanistan       AFG
# 1         248                       Åland Islands       ALA
# 2           8                             Albania       ALB
# 3          12                             Algeria       DZA
# 4          20                             Andorra       AND
# ..        ...                                 ...       ...
# 198       862  Venezuela (Bolivarian Republic of)       VEN
# 199       704                            Viet Nam       VNM
# 200       887                               Yemen       YEM
# 201       894                              Zambia       ZMB
# 202       716                            Zimbabwe       ZWE
#
# [203 rows x 3 columns]

# %% [markdown]
# ## Consumer Price Food Indices
# Consumer Prices, Food Indices (2015 = 100), monthly

# %%
# filter out december only
df = df[df["Months"] == "December"]
df = df[["Area Code (M49)", "Year", "Value"]]
print(df.shape)

# copy over cpi values
def copy_over(year, df_tmp):
    df_col = df[df["Year"] == year].copy()
    df_col = df_col[["Area Code (M49)", "Value"]]
    assert df_col.shape[0] == df_tmp.shape[0]
    df_tmp = df_tmp.join(df_col.set_index("Area Code (M49)"), on="M49_Code", validate="1:1")
    df_tmp["Value"] = df_tmp["Value"].apply(lambda x: float(x))
    df_tmp = df_tmp.rename(columns={"Value": "CPI_Food_%d" % year})
    return df_tmp
df_new = copy_over(2016, df_new)
df_new = copy_over(2017, df_new)
df_new = copy_over(2018, df_new)
df_new = copy_over(2019, df_new)
df_new = copy_over(2020, df_new)
df_new
# Out:
# (1015, 3)
#      M49_Code                        Country_Name ISO3 Code  CPI_Food_2016  \
# 0           4                         Afghanistan       AFG     108.916832
# 1         248                       Åland Islands       ALA      99.614148
# 2           8                             Albania       ALB     104.588667
# 3          12                             Algeria       DZA     105.435418
# 4          20                             Andorra       AND     101.932302
# ..        ...                                 ...       ...            ...
# 198       862  Venezuela (Bolivarian Republic of)       VEN     953.574367
# 199       704                            Viet Nam       VNM     103.139639
# 200       887                               Yemen       YEM     121.903092
# 201       894                              Zambia       ZMB     125.120587
# 202       716                            Zimbabwe       ZWE      96.878032
#
#      CPI_Food_2017  CPI_Food_2018  CPI_Food_2019  CPI_Food_2020
# 0       113.832502   1.134903e+02   1.190679e+02   1.280021e+02
# 1       100.584200   1.013542e+02   1.045143e+02   1.033243e+02
# 2       107.497139   1.106383e+02   1.134304e+02   1.163389e+02
# 3       111.015653   1.108684e+02   1.106159e+02   1.133403e+02
# 4       104.825577   1.068286e+02   1.084978e+02   1.096106e+02
# ..             ...            ...            ...            ...
# 198   11086.187138   1.594700e+07   1.288889e+09   3.875371e+10
# 199     101.286235   1.064430e+02   1.161996e+02   1.193164e+02
# 200     128.044919   1.349019e+02   1.439082e+02   1.529995e+02
# 201     131.148498   1.417520e+02   1.633637e+02   1.963545e+02
# 202     103.383454   1.587674e+02   1.300733e+03   5.806528e+03
#
# [203 rows x 8 columns]

# %%
# add a column for average over the years
columns = df_new.columns[-5:]
df_new["CPI_Food_Avg"] = df_new[columns].mean(axis=1)
df_new.head()
# Out:
#    M49_Code   Country_Name ISO3 Code  CPI_Food_2016  CPI_Food_2017  \
# 0         4    Afghanistan       AFG     108.916832     113.832502
# 1       248  Åland Islands       ALA      99.614148     100.584200
# 2         8        Albania       ALB     104.588667     107.497139
# 3        12        Algeria       DZA     105.435418     111.015653
# 4        20        Andorra       AND     101.932302     104.825577
#
#    CPI_Food_2018  CPI_Food_2019  CPI_Food_2020  CPI_Food_Avg
# 0     113.490296     119.067918     128.002089    116.661927
# 1     101.354238     104.514337     103.324285    101.878242
# 2     110.638289     113.430423     116.338895    110.498683
# 3     110.868390     110.615938     113.340313    110.255142
# 4     106.828613     108.497810     109.610608    106.338982

# %%
# prettify the float
#df_new = df_new[df_new.columns[-6:]].applymap(na_action='ignore', func=lambda x: ".6f" % x)
with open("../datasets/CPI_Food_Processed.csv", "w", encoding="utf8") as f:
    df_new.to_csv(f, lineterminator="\n", index=False)

# %% [markdown]
# ## Stats

# %%
df_new.isnull().sum()
# Out:
# M49_Code         0
# Country_Name     0
# ISO3 Code        0
# CPI_Food_2016    0
# CPI_Food_2017    0
# CPI_Food_2018    0
# CPI_Food_2019    0
# CPI_Food_2020    0
# CPI_Food_Avg     0
# dtype: int64
