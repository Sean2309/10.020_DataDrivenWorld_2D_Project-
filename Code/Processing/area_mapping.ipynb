# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("..\Datasets\Original\AreaCode_ISO3Code_conversion.csv")
df.head(15)
# Out:
#     Country Code              Country  M49 Code ISO2 Code ISO3 Code  \
# 0              2          Afghanistan       4.0        AF       AFG
# 1           5100               Africa       2.0     F5100       X06
# 2            284        Åland Islands     248.0      F284       ALA
# 3              3              Albania       8.0        AL       ALB
# 4              4              Algeria      12.0        DZ       DZA
# 5              5       American Samoa      16.0        AS       ASM
# 6           5200             Americas      19.0     F5200       X21
# 7              6              Andorra      20.0        AD       AND
# 8              7               Angola      24.0        AO       AGO
# 9            258             Anguilla     660.0        AI       AIA
# 10          5848    Annex I countries     907.0     F5848     F5848
# 11          5600     Antarctic Region     912.0     F5600     F5600
# 12            30           Antarctica      10.0        AQ       ATA
# ...

# %%
df.columns
# Out:
# Index(['Country Code', 'Country', 'M49 Code', 'ISO2 Code', 'ISO3 Code',
#        'Start Year', 'End Year'],
#       dtype='object')
