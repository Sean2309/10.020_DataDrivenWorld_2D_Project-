# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import seaborn as sns

# %%
FEATURE = "External_Debt_Stock"
df = pd.read_csv("..\..\datasets\Original\%s.csv" % FEATURE)
df
# Out:
#                                          Country Name Country Code  \
# 0                                         Afghanistan          AFG
# 1                                             Albania          ALB
# 2                                             Algeria          DZA
# 3                                      American Samoa          ASM
# 4                                             Andorra          AND
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 09/16/2022          NaN
#
#                                         Series Name     Series Code  \
# 0    External debt stocks, total (DOD, current US$)  DT.DOD.DECT.CD
# 1    External debt stocks, total (DOD, current US$)  DT.DOD.DECT.CD
# 2    External debt stocks, total (DOD, current US$)  DT.DOD.DECT.CD
# 3    External debt stocks, total (DOD, current US$)  DT.DOD.DECT.CD
# 4    External debt stocks, total (DOD, current US$)  DT.DOD.DECT.CD
# ..                                              ...             ...
# 266                                             NaN             NaN
# 267                                             NaN             NaN
# 268                                             NaN             NaN
# 269                                             NaN             NaN
# 270                                             NaN             NaN
#
#     2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  2020 [YR2020]
# 0    2596050086.4  2751986638.9  2678760424.2  2661685956.5   3036369312.4
# 1    8516222980.3  9801454504.1  9875849866.7  9556855648.5  10859239096.8
# 2    5462929063.8  5706735537.1    5710413690  5492302707.3     5178215526
# 3              ..            ..            ..            ..             ..
# 4              ..            ..            ..            ..             ..
# ..            ...           ...           ...           ...            ...
# 266           NaN           NaN           NaN           NaN            NaN
# 267           NaN           NaN           NaN           NaN            NaN
# 268           NaN           NaN           NaN           NaN            NaN
# 269           NaN           NaN           NaN           NaN            NaN
# 270           NaN           NaN           NaN           NaN            NaN
#
# [271 rows x 9 columns]

# %% [markdown]
# ## Skeleton dataframe

# %%
columns = ["Country Code"]
df.drop_duplicates(subset=columns, keep="first")
df_new = df[columns[0]].unique()
df_new = pd.DataFrame(df_new, columns=columns)
df.rename(columns={"Country Code": "ISO3_Code"}, inplace=True)
df_new.rename(columns={"Country Code": "ISO3_Code"}, inplace=True)
df_new.shape
# Out:
# (267, 1)

# %%
df_code = pd.read_csv("../../datasets/Original/AreaCode_ISO3Code_conversion.csv")
df_code = df_code[["Country", "ISO3 Code", "M49 Code"]]
df_new = df_new.join(df_code.set_index("ISO3 Code"), on="ISO3_Code", validate="1:1")
df_new
# Out:
#     ISO3_Code         Country  M49 Code
# 0         AFG     Afghanistan       4.0
# 1         ALB         Albania       8.0
# 2         DZA         Algeria      12.0
# 3         ASM  American Samoa      16.0
# 4         AND         Andorra      20.0
# ..        ...             ...       ...
# 262       SSA             NaN       NaN
# 263       TSS             NaN       NaN
# 264       UMC             NaN       NaN
# 265       WLD             NaN       NaN
# 266       NaN             NaN       NaN
#
# [267 rows x 3 columns]

# %%
df_new.rename(columns={"ISO3 Code": "ISO3_Code", "Country": "Country_Name", "M49 Code": "M49_Code"}, inplace=True)
df_new.head()
# Out:
#   ISO3_Code    Country_Name  M49_Code
# 0       AFG     Afghanistan       4.0
# 1       ALB         Albania       8.0
# 2       DZA         Algeria      12.0
# 3       ASM  American Samoa      16.0
# 4       AND         Andorra      20.0

# %%
df_new[df_new["Country_Name"].isnull()]
# Out:
#     ISO3_Code Country_Name  M49_Code
# 39        CHI          NaN       NaN
# 105       XKX          NaN       NaN
# 217       AFE          NaN       NaN
# 218       AFW          NaN       NaN
# 219       ARB          NaN       NaN
# 220       CSS          NaN       NaN
# 221       CEB          NaN       NaN
# 222       EAR          NaN       NaN
# 223       EAS          NaN       NaN
# 224       EAP          NaN       NaN
# 225       TEA          NaN       NaN
# 226       EMU          NaN       NaN
# 227       ECS          NaN       NaN
# 228       ECA          NaN       NaN
# 229       TEC          NaN       NaN
# 230       EUU          NaN       NaN
# 231       FCS          NaN       NaN
# 232       HPC          NaN       NaN
# 233       HIC          NaN       NaN
# 234       IBD          NaN       NaN
# 235       IBT          NaN       NaN
# 236       IDB          NaN       NaN
# 237       IDX          NaN       NaN
# 238       IDA          NaN       NaN
# 239       LTE          NaN       NaN
# 240       LCN          NaN       NaN
# 241       LAC          NaN       NaN
# 242       TLA          NaN       NaN
# 243       LDC          NaN       NaN
# 244       LMY          NaN       NaN
# 245       LIC          NaN       NaN
# 246       LMC          NaN       NaN
# 247       MEA          NaN       NaN
# 248       MNA          NaN       NaN
# 249       TMN          NaN       NaN
# 250       MIC          NaN       NaN
# 251       NAC          NaN       NaN
# 252       INX          NaN       NaN
# 253       OED          NaN       NaN
# 254       OSS          NaN       NaN
# 255       PSS          NaN       NaN
# 256       PST          NaN       NaN
# 257       PRE          NaN       NaN
# 258       SST          NaN       NaN
# 259       SAS          NaN       NaN
# 260       TSA          NaN       NaN
# 261       SSF          NaN       NaN
# 262       SSA          NaN       NaN
# 263       TSS          NaN       NaN
# 264       UMC          NaN       NaN
# 265       WLD          NaN       NaN
# 266       NaN          NaN       NaN

# %%
# drop the null rows cause it's the legend
df_new.dropna(inplace=True)
df_new
# Out:
#     ISO3_Code                  Country_Name  M49_Code
# 0         AFG                   Afghanistan       4.0
# 1         ALB                       Albania       8.0
# 2         DZA                       Algeria      12.0
# 3         ASM                American Samoa      16.0
# 4         AND                       Andorra      20.0
# ..        ...                           ...       ...
# 212       VIR  United States Virgin Islands     850.0
# 213       PSE                     Palestine     275.0
# 214       YEM                         Yemen     887.0
# 215       ZMB                        Zambia     894.0
# 216       ZWE                      Zimbabwe     716.0
#
# [215 rows x 3 columns]

# %% [markdown]
# ## Unemployment
# Unemployment (% of labor force)

# %%
df_tmp = pd.concat([df.loc[:, ["ISO3_Code"]], df.iloc[:, -5:]], axis=1)
df_new = df_new.merge(df_tmp, on="ISO3_Code", how="inner")
columns = df.columns[-5:].values
names_dict = {}
for i, column in enumerate(columns):
    names_dict[column] = "%s_%s" % (FEATURE, column[:4])
df_new.rename(columns=names_dict, inplace=True)
df_new
# Out:
#     ISO3_Code                  Country_Name  M49_Code  \
# 0         AFG                   Afghanistan       4.0
# 1         ALB                       Albania       8.0
# 2         DZA                       Algeria      12.0
# 3         ASM                American Samoa      16.0
# 4         AND                       Andorra      20.0
# ..        ...                           ...       ...
# 210       VIR  United States Virgin Islands     850.0
# 211       PSE                     Palestine     275.0
# 212       YEM                         Yemen     887.0
# 213       ZMB                        Zambia     894.0
# 214       ZWE                      Zimbabwe     716.0
#
#     External_Debt_Stock_2016 External_Debt_Stock_2017  \
# 0               2596050086.4             2751986638.9
# 1               8516222980.3             9801454504.1
# 2               5462929063.8             5706735537.1
# 3                         ..                       ..
# 4                         ..                       ..
# ..                       ...                      ...
# 210                       ..                       ..
# 211                       ..                       ..
# 212             7062871730.7             7193099657.9
# 213              15220653707            22954319549.1
# 214            11464935181.2            12510355251.4
#
#     External_Debt_Stock_2018 External_Debt_Stock_2019 External_Debt_Stock_2020
# 0               2678760424.2             2661685956.5             3036369312.4
# 1               9875849866.7             9556855648.5            10859239096.8
# 2                 5710413690             5492302707.3               5178215526
# 3                         ..                       ..                       ..
# 4                         ..                       ..                       ..
# ..                       ...                      ...                      ...
# 210                       ..                       ..                       ..
# 211                       ..                       ..                       ..
# 212               7036509959             7055218065.7             7120836024.2
# 213            23526271048.8            27726254062.8            30045885685.3
# 214              12620123760            12244515423.5            12740664732.3
#
# [215 rows x 8 columns]

# %%
# add a column for average over the years
columns = df_new.columns[-5:]
df_cols = df_new[columns].applymap(lambda x: float(x) if x not in ["", None, ".."] else None)
df_new = pd.concat([df_new.iloc[:, :3], df_cols], axis=1)
df_new["%s_Avg" % FEATURE] = df_new[columns].mean(axis=1)
df_new.head()
# Out:
#   ISO3_Code    Country_Name  M49_Code  External_Debt_Stock_2016  \
# 0       AFG     Afghanistan       4.0              2.596050e+09
# 1       ALB         Albania       8.0              8.516223e+09
# 2       DZA         Algeria      12.0              5.462929e+09
# 3       ASM  American Samoa      16.0                       NaN
# 4       AND         Andorra      20.0                       NaN
#
#    External_Debt_Stock_2017  External_Debt_Stock_2018  \
# 0              2.751987e+09              2.678760e+09
# 1              9.801455e+09              9.875850e+09
# 2              5.706736e+09              5.710414e+09
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    External_Debt_Stock_2019  External_Debt_Stock_2020  External_Debt_Stock_Avg
# 0              2.661686e+09              3.036369e+09             2.744970e+09
# 1              9.556856e+09              1.085924e+10             9.721924e+09
# 2              5.492303e+09              5.178216e+09             5.510119e+09
# 3                       NaN                       NaN                      NaN
# 4                       NaN                       NaN                      NaN

# %%
# prettify the float
#df_new = df_new[df_new.columns[-6:]].applymap(na_action='ignore', func=lambda x: ".6f" % x)
with open("../../datasets/Processed/%s_Processed.csv" % FEATURE, "w", encoding="utf8") as f:
    df_new.to_csv(f, lineterminator="\n", index=False)

# %% [markdown]
# ## Stats

# %%
df_new.isnull().sum()
# Out:
# ISO3_Code                    0
# Country_Name                 0
# M49_Code                     0
# External_Debt_Stock_2016    93
# External_Debt_Stock_2017    93
# External_Debt_Stock_2018    93
# External_Debt_Stock_2019    93
# External_Debt_Stock_2020    93
# External_Debt_Stock_Avg     93
# dtype: int64
