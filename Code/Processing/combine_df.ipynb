# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore')

# %%
df_socio = pd.read_excel("Datasets\Processed\Combined_Process_Factors.xlsx", "Socio_factors_processed")
df_cpi = pd.read_excel("Datasets\Processed\Combined_Process_Factors.xlsx", "CPI_processed")
df_fdi = pd.read_excel("Datasets\Processed\Combined_Process_Factors.xlsx", "Net_FDI_processed")
df_undernourishment = pd.read_excel("Datasets\Processed\Combined_Process_Factors.xlsx", "undernourishment_processed")
df_cpi.columns
# Out:
# Index(['M49_Code', 'Country_Name', 'ISO3 Code', 'CPI_Food_2016',
#        'CPI_Food_2017', 'CPI_Food_2018', 'CPI_Food_2019', 'CPI_Food_2020',
#        'CPI_Food_Avg'],
#       dtype='object')

# %%
df_cpi.drop(["M49_Code", "ISO3 Code"], inplace=True, axis=1)
df_fdi.drop(["Unnamed: 0", "M49_Code"], inplace=True, axis=1)
df_undernourishment.drop(["Unnamed: 0", "M49_Code"], inplace=True, axis=1)

# %%
df_combined = pd.merge(df_socio, df_cpi, on="Country_Name", how="inner")
df_combined = pd.merge(df_combined, df_fdi, on="Country_Name", how="inner")
df_combined = pd.merge(df_combined, df_undernourishment, on="Country_Name", how="inner")
df_combined.columns
# df_combined.to_csv("combined_df.csv")
# Out:
# Index(['ISO3_Code', 'Country_Name', 'M49_Code', 'Life_Expectancy_2016',
#        'Life_Expectancy_2017', 'Life_Expectancy_2018', 'Life_Expectancy_2019',
#        'Life_Expectancy_2020', 'Life_Expectancy_Avg',
#        'Mean_Years_Of_Schooling_2016', 'Mean_Years_Of_Schooling_2017',
#        'Mean_Years_Of_Schooling_2018', 'Mean_Years_Of_Schooling_2019',
#        'Mean_Years_Of_Schooling_2020', 'Mean_Years_of_Schooling_Avg',
#        'CPI_Food_2016', 'CPI_Food_2017', 'CPI_Food_2018', 'CPI_Food_2019',
#        'CPI_Food_2020', 'CPI_Food_Avg', 'Total_FDI_Inflows_2016',
#        'Total_FDI_Inflows_2017', 'Total_FDI_Inflows_2018',
#        'Total_FDI_Inflows_2019', 'Total_FDI_Inflows_2020',
#        'Total_FDI_Outflows_2016', 'Total_FDI_Outflows_2017',
#        'Total_FDI_Outflows_2018', 'Total_FDI_Outflows_2019',
#        'Total_FDI_Outflows_2020', 'Net_FDI_2016', 'Net_FDI_2017',
#        'Net_FDI_2018', 'Net_FDI_2019', 'Net_FDI_2020',
#        'Prevalence_of_undernourishment_2016',
#        'Prevalence_of_undernourishment_2017',
#        'Prevalence_of_undernourishment_2018',
#        'Prevalence_of_undernourishment_2019',
#        'Prevalence_of_undernourishment_2020'],
#       dtype='object')

# %%
df_all_processed = pd.read_csv("Datasets\Processed\All_Processed.csv")
# df_all_processed.sort_values(["Country_Name", "Year"])

# %%
df_gni = pd.read_csv("Datasets\Original\FAOSTAT_data_en_11-22-2022.csv", encoding="ISO-8859-1")
# Out:
#      Domain Code            Domain  Area Code (M49)         Area  \
# 0             MK  Macro Indicators                4  Afghanistan
# 1             MK  Macro Indicators                4  Afghanistan
# 2             MK  Macro Indicators                4  Afghanistan
# 3             MK  Macro Indicators                4  Afghanistan
# 4             MK  Macro Indicators                4  Afghanistan
# ...          ...               ...              ...          ...
# 1050          MK  Macro Indicators              716     Zimbabwe
# 1051          MK  Macro Indicators              716     Zimbabwe
# 1052          MK  Macro Indicators              716     Zimbabwe
# 1053          MK  Macro Indicators              716     Zimbabwe
# 1054          MK  Macro Indicators              716     Zimbabwe
#
#       Element Code    Element  Item Code                   Item  Year Code  \
# 0             6110  Value US$      22011  Gross National Income       2016
# 1             6110  Value US$      22011  Gross National Income       2017
# 2             6110  Value US$      22011  Gross National Income       2018
# 3             6110  Value US$      22011  Gross National Income       2019
# 4             6110  Value US$      22011  Gross National Income       2020
# ...            ...        ...        ...                    ...        ...
# 1050          6110  Value US$      22011  Gross National Income       2016
# 1051          6110  Value US$      22011  Gross National Income       2017
# 1052          6110  Value US$      22011  Gross National Income       2018
# 1053          6110  Value US$      22011  Gross National Income       2019
# 1054          6110  Value US$      22011  Gross National Income       2020
#
#       Year      Unit         Value Flag  \
# 0     2016  millions  18199.126228    X
# 1     2017  millions  19145.017021    X
# 2     2018  millions  18610.257350    X
# 3     2019  millions  19205.244293    X
# 4     2020  millions  19982.204387    X
# ...    ...       ...           ...  ...
# 1050  2016  millions  18772.952346    X
# 1051  2017  millions  20079.596788    X
# 1052  2018  millions  22706.648353    X
# 1053  2019  millions  21550.107657    X
# 1054  2020  millions  21430.886292    X
#
#                              Flag Description  Note
# 0     Figure from international organizations   NaN
# 1     Figure from international organizations   NaN
# 2     Figure from international organizations   NaN
# 3     Figure from international organizations   NaN
# 4     Figure from international organizations   NaN
# ...                                       ...   ...
# 1050  Figure from international organizations   NaN
# 1051  Figure from international organizations   NaN
# 1052  Figure from international organizations   NaN
# 1053  Figure from international organizations   NaN
# 1054  Figure from international organizations   NaN
#
# [1055 rows x 15 columns]

# %%
df_all_processed = pd.read_csv("Datasets\Processed\All_Processed.csv")
df_all_processed.sort_values(["Country_Name", "Year"], inplace=True)
df_gni = pd.read_csv("Datasets\Original\GNI.csv", encoding="ISO-8859-1")
df_population = pd.read_csv("Datasets\Original\Population.csv", encoding="ISO-8859-1")
df_govt_exp = pd.read_csv("Datasets\Original\Govt_Expenditure.csv", encoding="ISO-8859-1")

df_gni.rename(columns={"Area Code (M49)": "M49_Code", "Area": "Country_Name", "Value": "GNI"}, inplace=True)
df_gni.drop(["Domain Code", "Domain", "Element Code", "Element", "Item Code", "Year Code", 'Flag','Flag Description', 'Note', "M49_Code", "Unit", "Item"], axis=1, inplace=True)
df_population.rename(columns={"Area Code (M49)": "M49_Code", "Area": "Country_Name", "Value": "Population"}, inplace=True)
df_population.drop(["Domain Code", "Domain", "Element Code", "Element", "Item Code", "Year Code", 'Flag','Flag Description', 'Note', "M49_Code", "Item", "Unit"], axis=1, inplace=True)

df_govt_exp.rename(columns={"Area Code (M49)": "M49_Code", "Area": "Country_Name", "Value": "Govt_Expenditure"}, inplace=True)
df_govt_exp.drop(["ï»¿Domain Code", "Domain", "Element Code", "Element", "Item Code", "Year Code", 'Flag','Flag Description', 'Note', "M49_Code", "Item", "Unit"], axis=1, inplace=True)


# print(df_faostats.columns)
# print(df_faostats1.columns)
# df_all_processed.columns

df_combined1 = pd.merge(df_all_processed, df_gni, on=["Country_Name", "Year"], how="inner")
df_combined1 = pd.merge(df_combined1, df_population, on=["Country_Name", "Year"], how="inner")
df_combined1 = pd.merge(df_combined1, df_govt_exp, on=["Country_Name", "Year"], how="inner")


df_combined1
# Out:
#     ISO3_Code Country_Name  M49_Code  Year  Life_Expectancy  \
# 0         AFG  Afghanistan       4.0  2016          63.1361
# 1         AFG  Afghanistan       4.0  2017          63.0160
# 2         ALB      Albania       8.0  2016          78.8602
# 3         ALB      Albania       8.0  2017          79.0473
# 4         ALB      Albania       8.0  2018          79.1838
# ..        ...          ...       ...   ...              ...
# 363       VNM     Viet Nam     704.0  2016          73.9382
# 364       VNM     Viet Nam     704.0  2017          73.9632
# 365       VNM     Viet Nam     704.0  2018          73.9757
# 366       VNM     Viet Nam     704.0  2019          74.0929
# 367       VNM     Viet Nam     704.0  2020          75.3779
#
#      Mean_Years_Of_Schooling    CPI_Food       Net_FDI  \
# 0                   2.463660  108.916832     78.810000
# 1                   2.561425  113.832502     42.590000
# 2                  10.727528  104.588667   1036.471408
# 3                  10.910692  107.497139   1122.694050
# 4                  11.096983  110.638289   1207.129445
# ..                       ...         ...           ...
# 363                 8.122675  103.139639  11600.000000
# 364                 8.205210  101.286235  13620.000000
# 365                 8.287745  106.442999  14902.000000
# 366                 8.370280  116.199618  15655.000000
# 367                 8.370280  119.316440  15420.000000
#
#      Prevalence_of_undernourishment            GNI  Population  \
# 0                              22.2   18199.126228   34636.207
# 1                              23.0   19145.017021   35643.418
# 2                               4.7   12053.991102    2881.063
# 3                               4.7   13051.517242    2879.355
# 4                               4.6   15137.999954    2877.013
# ..                              ...            ...         ...
# 363                             7.8  196686.612085   93126.529
# 364                             7.2  207929.413476   94033.048
# 365                             6.8  230004.225280   94914.330
# 366                             6.2  246721.274433   95776.716
# 367                             5.7  255422.424127   96648.685
#
#      Govt_Expenditure
# 0         9299.089340
# 1         9095.510866
# 2         3428.258517
# 3         3805.991340
# 4         4355.901378
# ..                ...
# 363      59188.053379
# 364      60573.480112
# 365      63509.062231
# 366      75833.781920
# 367      77039.022071
#
# [368 rows x 12 columns]

# %%
df_combined1.to_csv("combined_df1.csv")
